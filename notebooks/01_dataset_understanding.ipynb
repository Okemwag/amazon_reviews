# %% [markdown]
# # Amazon Reviews Exploratory Analysis
#
# This notebook is a placeholder for screenshots or optional local analysis. The required Big Data analysis is implemented by the pipeline package under `src/amazon_reviews_pipeline/`.
